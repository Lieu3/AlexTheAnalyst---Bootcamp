# %% [markdown]
# ![image_2023-07-18_131031175.png](data:image/png;base64,...)

# %%
#Comparison Operators
10 == 10
# Out:
# True

# %%
10 == 50
# Out:
# False

# %%
10 != 50
# Out:
# True

# %%
'Vanilla' == 'Vanilla'
# Out:
# True

# %%
x = 'Vanilla'
y = 'Chocolate'

x == y
# Out:
# False

# %%
x = 'Vanilla'
y = 'Chocolate'

x != y
# Out:
# True

# %%
10 < 10
# Out:
# False

# %%
10 <= 10
# Out:
# True

# %% [markdown]
# ![image_2023-07-18_131059772.png](data:image/png;base64,...)

# %%
#Logical Operators
(10 > 50) and (50>10)
# Out:
# False

# %%
(70 > 50) and (50>10)
# Out:
# True

# %%
(10 > 50) or (50>10)
# Out:
# True

# %%
#also works with strings, this works because numberical V is more than C
 ('Vanilla' > 'Chocolate') and (50>10)
# Out:
# True

# %%
not(50>10)
# Out:
# False

# %% [markdown]
# ![image_2023-07-18_131714440.png](data:image/png;base64,...)

# %%
#Membership Operators

ice_cream = 'I love Chocolate ice cream'
'love' in ' I love Chocolate ice cream'
# Out:
# True

# %%
scoops = [1,2,3,4,5]
6 not in scoops
# Out:
# True

# %%
scoops = [1,2,3,4,5]
wanted_scoops = 8
wanted_scoops in scoops
# Out:
# False
